# %% [markdown]
# <a href="https://colab.research.google.com/github/GangaHemalatha/WEB-SCRAPPING/blob/main/KFC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Scrap data from Flipkart for Redmi Mobile Phones

from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

url = "https://www.swiggy.com/restaurants/kfc-kachiguda-hyderabad-419707"
p = requests.get(url)
soup = BeautifulSoup(p.content,'html.parser')
print(p)
content = soup.find_all('div', class_="_2wg_t")
fheader = ["food item","price"]

itemfull = []

for item in content:
  items = []
  fooditem = item.find('h3', class_="styles_itemNameText__3ZmZZ")
  price = item.find('span', class_="styles_price__2xrhD styles_itemPrice__1Nrpd styles_s__66zLz")
  
  
  if(fooditem is not None):
    items.append(fooditem.text)
  else:
    items.append("food item is NA")
  if(price is not None):
    items.append(price.text)
  else:
    items.append("price is NA")
  
  itemfull.append(items)

pd.DataFrame(itemfull).to_csv("KFC.csv",header=fheader)
# Out:
# <Response [200]>

# %%
data= pd.read_csv("KFC.csv")

# %%
import matplotlib
import matplotlib.pyplot as plt


x = [795.24, 719.05, 819.05, 788.57, 740, 879.05, 879.05, 479.05]

fig, ax = plt.subplots()
ax.plot(x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Guido')

plt.xlabel('food item')
plt.ylabel('price')
plt.title('KFC')
plt.xticks(index + bar_width, ('Biryanicombo', 'Stay Home Bucket', 'Family Feast', 'Mingles Bucket Meal'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
  
x = np.array(['Biryanicombo', 'Stay Home Bucket', 'Family Feast', 'Mingles Bucket Meal'])
y =795.25, 788.57, 828.57, 479.05
  
plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("KFC.csv")
plt.show()  
  

plt.figure()
x1 = ['Biryanicombo', 'Stay Home Bucket', 'Family Feast', 'Mingles Bucket Meal']
y1 = [795.25, 788.57, 828.57, 479.05]
plt.plot(x1, y1, '-.')
  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
x = np.random.rand(10)
y = np.random.rand(10)
z = np.random.rand(10)
colors = np.random.rand(10) 
plt.scatter(x, y, s=z*1000,c=colors)
plt.show()

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
 
 
# Creating dataset
fooditems = ['Biryanicombo', 'Stay Home Bucket', 'Family Feast']
 
data = [23, 17, 41]
 
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = fooditems)
 
plt.show()
